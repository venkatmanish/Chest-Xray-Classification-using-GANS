# %% [markdown]
# # Importing Dependencies

# %%
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
import os,re,h5py
import time
from tensorflow.keras.preprocessing import image
from keras.applications.imagenet_utils import preprocess_input
from keras.layers import Dense, Activation, Flatten,Conv2D,MaxPooling2D, Dropout,BatchNormalization,ZeroPadding2D,Concatenate,Input
from keras.models import Model
from keras.callbacks import CSVLogger, ReduceLROnPlateau
from keras.models import Sequential
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from keras.optimizers import Adam
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
from sklearn.utils import shuffle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Define Paths

# %%
PATH = "/content/drive/MyDrive/minor_gans/new_chest_xray"
METRICS_PATH="/content/drive/MyDrive/minor_gans/output/alexnet/"
MODEL_NAME="AlexNetgans"
print("PWD", PATH)
# Out:
# PWD /content/drive/MyDrive/minor_gans/new_chest_xray

# %% [markdown]
# # Define Metrics

# %%
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

# %%
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    false_positives = K.sum(K.round(K.clip((1 - y_true) * y_pred, 0, 1)))
    return true_negatives / (true_negatives+false_positives + K.epsilon())

# %%
def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall
    def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# # Read Images from drive

# %%
def sorted_alphanumeric(data):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)', key)]
    return sorted(data, key=alphanum_key)

# %%
data_path = PATH
data_dir_list = sorted_alphanumeric(os.listdir(data_path))
print(data_dir_list)
# Out:
# ['NORMAL', 'PNEUMONIA']

# %%
img_data_list = []

for dataset in data_dir_list:
    img_list = sorted_alphanumeric(os.listdir(data_path + '/' + dataset))
    print('Loaded the images of dataset-' + '{}\n'.format(dataset))
    for img in img_list:
        img_path = data_path + '/' + dataset + '/' + img
        img = image.load_img(img_path, target_size=(32,32))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        x = x/255
        img_data_list.append(x)
# Out:
# Loaded the images of dataset-NORMAL
#
# Loaded the images of dataset-PNEUMONIA

# %%
img_data = np.array(img_data_list)
print(img_data.shape)
img_data = np.rollaxis(img_data, 1, 0)
print(img_data.shape)
img_data = img_data[0]
print(img_data.shape)
# Out:
# (7856, 1, 32, 32, 3)
# (1, 7856, 32, 32, 3)
# (7856, 32, 32, 3)

# %% [markdown]
# # Train and Test Data

# %%
num_classes = 2
num_of_samples = img_data.shape[0]
print("sample", num_of_samples)
labels = np.ones((num_of_samples,), dtype='int64')
labels[0:1584] = 0
labels[1584:] = 1
names = ['NORMAL', 'PNEUMONIA']
# Out:
# sample 7856

# %%
Y = np_utils.to_categorical(labels, num_classes)
x, y = shuffle(img_data, Y, random_state=2)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %% [markdown]
# # Model Architecture

# %%
model = Sequential()
model.add(ZeroPadding2D(1, input_shape=(32,32,3)))
model.add(Conv2D(96, (5,5), activation='relu'))
model.add(BatchNormalization())

model.add(Conv2D(256, (5, 5), activation='relu'))
model.add(BatchNormalization())

model.add(Dropout(0.3, name='dropout_1'))
model.add(MaxPooling2D(pool_size=(2, 2), name='block1_maxpooling2'))
model.add(Conv2D(384, (3, 3), activation='relu', name='block1_conv3', padding='same'))

model.add(Conv2D(384, (3, 3), activation='relu', name='block1_conv4', padding='same'))
model.add(Conv2D(256, (3, 3), activation='relu', name='block1_conv5', padding='same'))
model.add(Dropout(0.4, name='dropout_2'))
model.add(Flatten(name='flatten'))
# model.add(Dense(512, activation='relu', name='fc'))
# model.add(Dropout(0.5, name='dropout_3'))
model.add(Dense(4096, activation='relu', name='fc2'))
model.add(Dropout(0.5, name='dropout_4'))
model.add(Dense(4096, activation='relu', name='fc1'))
model.add(Dropout(0.5, name='dropout_5'))
model.add(Dense(2, activation='softmax', name='predictions'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  zero_padding2d (ZeroPadding  (None, 34, 34, 3)        0
#  2D)
#
#  conv2d (Conv2D)             (None, 30, 30, 96)        7296
#
#  batch_normalization (BatchN  (None, 30, 30, 96)       384
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 26, 26, 256)       614656
#
#  batch_normalization_1 (Batc  (None, 26, 26, 256)      1024
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 26, 26, 256)       0
#
#  block1_maxpooling2 (MaxPool  (None, 13, 13, 256)      0
#  ing2D)
#
#  block1_conv3 (Conv2D)       (None, 13, 13, 384)       885120
#
#  block1_conv4 (Conv2D)       (None, 13, 13, 384)       1327488
#
#  block1_conv5 (Conv2D)       (None, 13, 13, 256)       884992
#
#  dropout_2 (Dropout)         (None, 13, 13, 256)       0
#
#  flatten (Flatten)           (None, 43264)             0
#
#  fc2 (Dense)                 (None, 4096)              177213440
#
#  dropout_4 (Dropout)         (None, 4096)              0
#
#  fc1 (Dense)                 (None, 4096)              16781312
#
#  dropout_5 (Dropout)         (None, 4096)              0
#
#  predictions (Dense)         (None, 2)                 8194
#
# =================================================================
# Total params: 197,723,906
# Trainable params: 197,723,202
# Non-trainable params: 704
# _________________________________________________________________

# %%
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1), cooldown=0, patience=2, min_lr=0.5e-6)
csv_logger = CSVLogger(METRICS_PATH+MODEL_NAME+'.csv', append=True, separator=';')

adam = Adam(lr=0.00006, beta_1=0.9, beta_2=0.99, epsilon=None, decay=1e-6, amsgrad=False)


# Let's train the model using Adam
model.compile(loss='binary_crossentropy',
              optimizer=adam,
              metrics=['accuracy', f1, sensitivity, specificity])


x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %% [markdown]
# # Model Training

# %% [markdown]
# ### With Augumentation

# %%
batch_size = 16
data_augmentation = True
epochs = 100

# %%
import time
start_time = time.time()

if not data_augmentation:
    print('Not using data augmentation.')
    history = model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True, callbacks=[lr_reducer,csv_logger])
else:
    print('Using real-time data augmentation.')
    datagen = ImageDataGenerator(
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True)  # randomly flip images
    datagen.fit(x_train)
    history = model.fit_generator(datagen.flow(x_train, y_train,
                                               batch_size=batch_size),
                                  epochs=epochs,
                                  validation_data=(x_test, y_test), callbacks=[lr_reducer, csv_logger])
# Out:
# Using real-time data augmentation.
# <ipython-input-16-eb7f1dcb9614>:19: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(datagen.flow(x_train, y_train,
# Epoch 1/100
# 1378/1378 [==============================] - 107s 69ms/step - loss: 0.3504 - accuracy: 0.8482 - f1: 0.8481 - sensitivity: 0.8481 - specificity: 0.8481 - val_loss: 0.1633 - val_accuracy: 0.9447 - val_f1: 0.9449 - val_sensitivity: 0.9449 - val_specificity: 0.9449 - lr: 6.0000e-05
# Epoch 2/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.1771 - accuracy: 0.9444 - f1: 0.9444 - sensitivity: 0.9444 - specificity: 0.9444 - val_loss: 0.1490 - val_accuracy: 0.9514 - val_f1: 0.9516 - val_sensitivity: 0.9516 - val_specificity: 0.9516 - lr: 6.0000e-05
# Epoch 3/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1616 - accuracy: 0.9499 - f1: 0.9499 - sensitivity: 0.9499 - specificity: 0.9499 - val_loss: 0.1539 - val_accuracy: 0.9530 - val_f1: 0.9532 - val_sensitivity: 0.9532 - val_specificity: 0.9532 - lr: 6.0000e-05
# Epoch 4/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1495 - accuracy: 0.9532 - f1: 0.9532 - sensitivity: 0.9532 - specificity: 0.9532 - val_loss: 0.1748 - val_accuracy: 0.9556 - val_f1: 0.9557 - val_sensitivity: 0.9557 - val_specificity: 0.9557 - lr: 6.0000e-05
# Epoch 5/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1271 - accuracy: 0.9588 - f1: 0.9588 - sensitivity: 0.9588 - specificity: 0.9588 - val_loss: 0.1652 - val_accuracy: 0.9565 - val_f1: 0.9566 - val_sensitivity: 0.9566 - val_specificity: 0.9566 - lr: 1.8974e-05
# Epoch 6/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1223 - accuracy: 0.9608 - f1: 0.9608 - sensitivity: 0.9608 - specificity: 0.9608 - val_loss: 0.1911 - val_accuracy: 0.9526 - val_f1: 0.9529 - val_sensitivity: 0.9529 - val_specificity: 0.9529 - lr: 1.8974e-05
# Epoch 7/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.1110 - accuracy: 0.9633 - f1: 0.9633 - sensitivity: 0.9633 - specificity: 0.9633 - val_loss: 0.3434 - val_accuracy: 0.9470 - val_f1: 0.9473 - val_sensitivity: 0.9473 - val_specificity: 0.9473 - lr: 6.0000e-06
# Epoch 8/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1107 - accuracy: 0.9627 - f1: 0.9627 - sensitivity: 0.9627 - specificity: 0.9627 - val_loss: 0.3695 - val_accuracy: 0.9474 - val_f1: 0.9476 - val_sensitivity: 0.9476 - val_specificity: 0.9476 - lr: 6.0000e-06
# Epoch 9/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.1054 - accuracy: 0.9637 - f1: 0.9637 - sensitivity: 0.9637 - specificity: 0.9637 - val_loss: 0.6120 - val_accuracy: 0.9383 - val_f1: 0.9386 - val_sensitivity: 0.9386 - val_specificity: 0.9386 - lr: 1.8974e-06
# Epoch 10/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1071 - accuracy: 0.9635 - f1: 0.9635 - sensitivity: 0.9635 - specificity: 0.9635 - val_loss: 0.6343 - val_accuracy: 0.9389 - val_f1: 0.9391 - val_sensitivity: 0.9391 - val_specificity: 0.9391 - lr: 1.8974e-06
# Epoch 11/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.1065 - accuracy: 0.9644 - f1: 0.9644 - sensitivity: 0.9644 - specificity: 0.9644 - val_loss: 0.7330 - val_accuracy: 0.9347 - val_f1: 0.9350 - val_sensitivity: 0.9350 - val_specificity: 0.9350 - lr: 6.0000e-07
# Epoch 12/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1048 - accuracy: 0.9638 - f1: 0.9638 - sensitivity: 0.9638 - specificity: 0.9638 - val_loss: 0.7251 - val_accuracy: 0.9354 - val_f1: 0.9357 - val_sensitivity: 0.9357 - val_specificity: 0.9357 - lr: 6.0000e-07
# Epoch 13/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1054 - accuracy: 0.9648 - f1: 0.9648 - sensitivity: 0.9648 - specificity: 0.9648 - val_loss: 0.8392 - val_accuracy: 0.9312 - val_f1: 0.9315 - val_sensitivity: 0.9315 - val_specificity: 0.9315 - lr: 5.0000e-07
# Epoch 14/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1031 - accuracy: 0.9643 - f1: 0.9643 - sensitivity: 0.9643 - specificity: 0.9643 - val_loss: 0.8544 - val_accuracy: 0.9302 - val_f1: 0.9305 - val_sensitivity: 0.9305 - val_specificity: 0.9305 - lr: 5.0000e-07
# Epoch 15/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.1033 - accuracy: 0.9650 - f1: 0.9650 - sensitivity: 0.9650 - specificity: 0.9650 - val_loss: 0.8859 - val_accuracy: 0.9292 - val_f1: 0.9296 - val_sensitivity: 0.9296 - val_specificity: 0.9296 - lr: 5.0000e-07
# Epoch 16/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.1029 - accuracy: 0.9654 - f1: 0.9654 - sensitivity: 0.9654 - specificity: 0.9654 - val_loss: 0.9613 - val_accuracy: 0.9265 - val_f1: 0.9268 - val_sensitivity: 0.9268 - val_specificity: 0.9268 - lr: 5.0000e-07
# Epoch 17/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1031 - accuracy: 0.9647 - f1: 0.9647 - sensitivity: 0.9647 - specificity: 0.9647 - val_loss: 1.0064 - val_accuracy: 0.9245 - val_f1: 0.9249 - val_sensitivity: 0.9249 - val_specificity: 0.9249 - lr: 5.0000e-07
# Epoch 18/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1031 - accuracy: 0.9648 - f1: 0.9648 - sensitivity: 0.9648 - specificity: 0.9648 - val_loss: 1.0873 - val_accuracy: 0.9218 - val_f1: 0.9221 - val_sensitivity: 0.9221 - val_specificity: 0.9221 - lr: 5.0000e-07
# Epoch 19/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.1036 - accuracy: 0.9651 - f1: 0.9651 - sensitivity: 0.9651 - specificity: 0.9651 - val_loss: 1.2456 - val_accuracy: 0.9147 - val_f1: 0.9151 - val_sensitivity: 0.9151 - val_specificity: 0.9151 - lr: 5.0000e-07
# Epoch 20/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1039 - accuracy: 0.9655 - f1: 0.9655 - sensitivity: 0.9655 - specificity: 0.9655 - val_loss: 1.1973 - val_accuracy: 0.9173 - val_f1: 0.9176 - val_sensitivity: 0.9176 - val_specificity: 0.9176 - lr: 5.0000e-07
# Epoch 21/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1036 - accuracy: 0.9640 - f1: 0.9640 - sensitivity: 0.9640 - specificity: 0.9640 - val_loss: 1.3091 - val_accuracy: 0.9158 - val_f1: 0.9162 - val_sensitivity: 0.9162 - val_specificity: 0.9162 - lr: 5.0000e-07
# Epoch 22/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.1025 - accuracy: 0.9646 - f1: 0.9646 - sensitivity: 0.9646 - specificity: 0.9646 - val_loss: 1.2833 - val_accuracy: 0.9167 - val_f1: 0.9171 - val_sensitivity: 0.9171 - val_specificity: 0.9171 - lr: 5.0000e-07
# Epoch 23/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.0991 - accuracy: 0.9666 - f1: 0.9666 - sensitivity: 0.9666 - specificity: 0.9666 - val_loss: 1.5623 - val_accuracy: 0.9073 - val_f1: 0.9077 - val_sensitivity: 0.9077 - val_specificity: 0.9077 - lr: 5.0000e-07
# Epoch 24/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1039 - accuracy: 0.9645 - f1: 0.9645 - sensitivity: 0.9645 - specificity: 0.9645 - val_loss: 1.5091 - val_accuracy: 0.9087 - val_f1: 0.9091 - val_sensitivity: 0.9091 - val_specificity: 0.9091 - lr: 5.0000e-07
# Epoch 25/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1015 - accuracy: 0.9654 - f1: 0.9654 - sensitivity: 0.9654 - specificity: 0.9654 - val_loss: 1.5051 - val_accuracy: 0.9104 - val_f1: 0.9108 - val_sensitivity: 0.9108 - val_specificity: 0.9108 - lr: 5.0000e-07
# Epoch 26/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.1024 - accuracy: 0.9645 - f1: 0.9645 - sensitivity: 0.9645 - specificity: 0.9645 - val_loss: 1.5817 - val_accuracy: 0.9087 - val_f1: 0.9091 - val_sensitivity: 0.9091 - val_specificity: 0.9091 - lr: 5.0000e-07
# Epoch 27/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1012 - accuracy: 0.9650 - f1: 0.9650 - sensitivity: 0.9650 - specificity: 0.9650 - val_loss: 1.7000 - val_accuracy: 0.9064 - val_f1: 0.9068 - val_sensitivity: 0.9068 - val_specificity: 0.9068 - lr: 5.0000e-07
# Epoch 28/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.1027 - accuracy: 0.9647 - f1: 0.9647 - sensitivity: 0.9647 - specificity: 0.9647 - val_loss: 1.9017 - val_accuracy: 0.8977 - val_f1: 0.8981 - val_sensitivity: 0.8981 - val_specificity: 0.8981 - lr: 5.0000e-07
# Epoch 29/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1052 - accuracy: 0.9649 - f1: 0.9649 - sensitivity: 0.9649 - specificity: 0.9649 - val_loss: 1.8770 - val_accuracy: 0.9004 - val_f1: 0.9008 - val_sensitivity: 0.9008 - val_specificity: 0.9008 - lr: 5.0000e-07
# Epoch 30/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.1017 - accuracy: 0.9664 - f1: 0.9664 - sensitivity: 0.9664 - specificity: 0.9664 - val_loss: 1.8649 - val_accuracy: 0.9029 - val_f1: 0.9034 - val_sensitivity: 0.9034 - val_specificity: 0.9034 - lr: 5.0000e-07
# Epoch 31/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1017 - accuracy: 0.9658 - f1: 0.9658 - sensitivity: 0.9658 - specificity: 0.9658 - val_loss: 1.8768 - val_accuracy: 0.9019 - val_f1: 0.9023 - val_sensitivity: 0.9023 - val_specificity: 0.9023 - lr: 5.0000e-07
# Epoch 32/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1023 - accuracy: 0.9649 - f1: 0.9649 - sensitivity: 0.9649 - specificity: 0.9649 - val_loss: 2.0819 - val_accuracy: 0.8962 - val_f1: 0.8967 - val_sensitivity: 0.8967 - val_specificity: 0.8967 - lr: 5.0000e-07
# Epoch 33/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.1024 - accuracy: 0.9656 - f1: 0.9656 - sensitivity: 0.9656 - specificity: 0.9656 - val_loss: 2.2148 - val_accuracy: 0.8940 - val_f1: 0.8945 - val_sensitivity: 0.8945 - val_specificity: 0.8945 - lr: 5.0000e-07
# Epoch 34/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1007 - accuracy: 0.9658 - f1: 0.9658 - sensitivity: 0.9658 - specificity: 0.9658 - val_loss: 2.5838 - val_accuracy: 0.8844 - val_f1: 0.8849 - val_sensitivity: 0.8849 - val_specificity: 0.8849 - lr: 5.0000e-07
# Epoch 35/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.1019 - accuracy: 0.9655 - f1: 0.9655 - sensitivity: 0.9655 - specificity: 0.9655 - val_loss: 2.4250 - val_accuracy: 0.8922 - val_f1: 0.8927 - val_sensitivity: 0.8927 - val_specificity: 0.8927 - lr: 5.0000e-07
# Epoch 36/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.0995 - accuracy: 0.9659 - f1: 0.9659 - sensitivity: 0.9659 - specificity: 0.9659 - val_loss: 2.5779 - val_accuracy: 0.8870 - val_f1: 0.8875 - val_sensitivity: 0.8875 - val_specificity: 0.8875 - lr: 5.0000e-07
# Epoch 37/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.1023 - accuracy: 0.9646 - f1: 0.9646 - sensitivity: 0.9646 - specificity: 0.9646 - val_loss: 2.7221 - val_accuracy: 0.8835 - val_f1: 0.8840 - val_sensitivity: 0.8840 - val_specificity: 0.8840 - lr: 5.0000e-07
# Epoch 38/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0995 - accuracy: 0.9660 - f1: 0.9660 - sensitivity: 0.9660 - specificity: 0.9660 - val_loss: 3.0685 - val_accuracy: 0.8723 - val_f1: 0.8728 - val_sensitivity: 0.8728 - val_specificity: 0.8728 - lr: 5.0000e-07
# Epoch 39/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.1029 - accuracy: 0.9653 - f1: 0.9653 - sensitivity: 0.9653 - specificity: 0.9653 - val_loss: 3.0465 - val_accuracy: 0.8741 - val_f1: 0.8746 - val_sensitivity: 0.8746 - val_specificity: 0.8746 - lr: 5.0000e-07
# Epoch 40/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.0993 - accuracy: 0.9654 - f1: 0.9654 - sensitivity: 0.9654 - specificity: 0.9654 - val_loss: 3.2275 - val_accuracy: 0.8665 - val_f1: 0.8671 - val_sensitivity: 0.8671 - val_specificity: 0.8671 - lr: 5.0000e-07
# Epoch 41/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1010 - accuracy: 0.9653 - f1: 0.9653 - sensitivity: 0.9653 - specificity: 0.9653 - val_loss: 3.1364 - val_accuracy: 0.8716 - val_f1: 0.8721 - val_sensitivity: 0.8721 - val_specificity: 0.8721 - lr: 5.0000e-07
# Epoch 42/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.1015 - accuracy: 0.9655 - f1: 0.9655 - sensitivity: 0.9655 - specificity: 0.9655 - val_loss: 3.5859 - val_accuracy: 0.8567 - val_f1: 0.8568 - val_sensitivity: 0.8568 - val_specificity: 0.8568 - lr: 5.0000e-07
# Epoch 43/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.1010 - accuracy: 0.9653 - f1: 0.9653 - sensitivity: 0.9653 - specificity: 0.9653 - val_loss: 3.7259 - val_accuracy: 0.8541 - val_f1: 0.8542 - val_sensitivity: 0.8542 - val_specificity: 0.8542 - lr: 5.0000e-07
# Epoch 44/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.0999 - accuracy: 0.9667 - f1: 0.9667 - sensitivity: 0.9667 - specificity: 0.9667 - val_loss: 3.7357 - val_accuracy: 0.8596 - val_f1: 0.8596 - val_sensitivity: 0.8596 - val_specificity: 0.8596 - lr: 5.0000e-07
# Epoch 45/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.0991 - accuracy: 0.9666 - f1: 0.9666 - sensitivity: 0.9666 - specificity: 0.9666 - val_loss: 4.1786 - val_accuracy: 0.8469 - val_f1: 0.8470 - val_sensitivity: 0.8470 - val_specificity: 0.8470 - lr: 5.0000e-07
# Epoch 46/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.1027 - accuracy: 0.9656 - f1: 0.9656 - sensitivity: 0.9656 - specificity: 0.9656 - val_loss: 3.8368 - val_accuracy: 0.8570 - val_f1: 0.8577 - val_sensitivity: 0.8577 - val_specificity: 0.8577 - lr: 5.0000e-07
# Epoch 47/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.1009 - accuracy: 0.9661 - f1: 0.9661 - sensitivity: 0.9661 - specificity: 0.9661 - val_loss: 3.9302 - val_accuracy: 0.8536 - val_f1: 0.8537 - val_sensitivity: 0.8537 - val_specificity: 0.8537 - lr: 5.0000e-07
# Epoch 48/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.0995 - accuracy: 0.9657 - f1: 0.9657 - sensitivity: 0.9657 - specificity: 0.9657 - val_loss: 4.3441 - val_accuracy: 0.8449 - val_f1: 0.8450 - val_sensitivity: 0.8450 - val_specificity: 0.8450 - lr: 5.0000e-07
# Epoch 49/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.
100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0997 - accuracy: 0.9653 - f1: 0.9653 - sensitivity: 0.9653 - specificity: 0.9653 - val_loss: 8.0721 - val_accuracy: 0.7932 - val_f1: 0.7930 - val_sensitivity: 0.7930 - val_specificity: 0.7930 - lr: 5.0000e-07
# Epoch 63/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.0985 - accuracy: 0.9659 - f1: 0.9659 - sensitivity: 0.9659 - specificity: 0.9659 - val_loss: 8.1190 - val_accuracy: 0.7910 - val_f1: 0.7903 - val_sensitivity: 0.7903 - val_specificity: 0.7903 - lr: 5.0000e-07
# Epoch 64/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.1007 - accuracy: 0.9640 - f1: 0.9640 - sensitivity: 0.9640 - specificity: 0.9640 - val_loss: 8.4552 - val_accuracy: 0.7885 - val_f1: 0.7878 - val_sensitivity: 0.7878 - val_specificity: 0.7878 - lr: 5.0000e-07
# Epoch 65/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.0977 - accuracy: 0.9666 - f1: 0.9666 - sensitivity: 0.9666 - specificity: 0.9666 - val_loss: 8.2872 - val_accuracy: 0.7910 - val_f1: 0.7908 - val_sensitivity: 0.7908 - val_specificity: 0.7908 - lr: 5.0000e-07
# Epoch 66/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0981 - accuracy: 0.9661 - f1: 0.9661 - sensitivity: 0.9661 - specificity: 0.9661 - val_loss: 8.2621 - val_accuracy: 0.7917 - val_f1: 0.7915 - val_sensitivity: 0.7915 - val_specificity: 0.7915 - lr: 5.0000e-07
# Epoch 67/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.0967 - accuracy: 0.9667 - f1: 0.9667 - sensitivity: 0.9667 - specificity: 0.9667 - val_loss: 9.1638 - val_accuracy: 0.7834 - val_f1: 0.7827 - val_sensitivity: 0.7827 - val_specificity: 0.7827 - lr: 5.0000e-07
# Epoch 68/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.1000 - accuracy: 0.9667 - f1: 0.9667 - sensitivity: 0.9667 - specificity: 0.9667 - val_loss: 9.4114 - val_accuracy: 0.7770 - val_f1: 0.7758 - val_sensitivity: 0.7758 - val_specificity: 0.7758 - lr: 5.0000e-07
# Epoch 69/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.1006 - accuracy: 0.9667 - f1: 0.9667 - sensitivity: 0.9667 - specificity: 0.9667 - val_loss: 10.0957 - val_accuracy: 0.7683 - val_f1: 0.7672 - val_sensitivity: 0.7672 - val_specificity: 0.7672 - lr: 5.0000e-07
# Epoch 70/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.1002 - accuracy: 0.9662 - f1: 0.9662 - sensitivity: 0.9662 - specificity: 0.9662 - val_loss: 10.4948 - val_accuracy: 0.7661 - val_f1: 0.7650 - val_sensitivity: 0.7650 - val_specificity: 0.7650 - lr: 5.0000e-07
# Epoch 71/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0980 - accuracy: 0.9668 - f1: 0.9668 - sensitivity: 0.9668 - specificity: 0.9668 - val_loss: 11.2669 - val_accuracy: 0.7562 - val_f1: 0.7551 - val_sensitivity: 0.7551 - val_specificity: 0.7551 - lr: 5.0000e-07
# Epoch 72/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0986 - accuracy: 0.9652 - f1: 0.9652 - sensitivity: 0.9652 - specificity: 0.9652 - val_loss: 11.0118 - val_accuracy: 0.7658 - val_f1: 0.7646 - val_sensitivity: 0.7646 - val_specificity: 0.7646 - lr: 5.0000e-07
# Epoch 73/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0984 - accuracy: 0.9673 - f1: 0.9673 - sensitivity: 0.9673 - specificity: 0.9673 - val_loss: 11.2976 - val_accuracy: 0.7622 - val_f1: 0.7610 - val_sensitivity: 0.7610 - val_specificity: 0.7610 - lr: 5.0000e-07
# Epoch 74/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0990 - accuracy: 0.9661 - f1: 0.9661 - sensitivity: 0.9661 - specificity: 0.9661 - val_loss: 12.0374 - val_accuracy: 0.7556 - val_f1: 0.7545 - val_sensitivity: 0.7545 - val_specificity: 0.7545 - lr: 5.0000e-07
# Epoch 75/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0967 - accuracy: 0.9657 - f1: 0.9657 - sensitivity: 0.9657 - specificity: 0.9657 - val_loss: 11.4686 - val_accuracy: 0.7649 - val_f1: 0.7637 - val_sensitivity: 0.7637 - val_specificity: 0.7637 - lr: 5.0000e-07
# Epoch 76/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0979 - accuracy: 0.9658 - f1: 0.9658 - sensitivity: 0.9658 - specificity: 0.9658 - val_loss: 12.4485 - val_accuracy: 0.7534 - val_f1: 0.7523 - val_sensitivity: 0.7523 - val_specificity: 0.7523 - lr: 5.0000e-07
# Epoch 77/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0981 - accuracy: 0.9665 - f1: 0.9665 - sensitivity: 0.9665 - specificity: 0.9665 - val_loss: 12.4745 - val_accuracy: 0.7551 - val_f1: 0.7540 - val_sensitivity: 0.7540 - val_specificity: 0.7540 - lr: 5.0000e-07
# Epoch 78/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0963 - accuracy: 0.9676 - f1: 0.9676 - sensitivity: 0.9676 - specificity: 0.9676 - val_loss: 12.9355 - val_accuracy: 0.7513 - val_f1: 0.7502 - val_sensitivity: 0.7502 - val_specificity: 0.7502 - lr: 5.0000e-07
# Epoch 79/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.0981 - accuracy: 0.9667 - f1: 0.9667 - sensitivity: 0.9667 - specificity: 0.9667 - val_loss: 12.6607 - val_accuracy: 0.7545 - val_f1: 0.7534 - val_sensitivity: 0.7534 - val_specificity: 0.7534 - lr: 5.0000e-07
# Epoch 80/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.0966 - accuracy: 0.9672 - f1: 0.9672 - sensitivity: 0.9672 - specificity: 0.9672 - val_loss: 12.7675 - val_accuracy: 0.7549 - val_f1: 0.7538 - val_sensitivity: 0.7538 - val_specificity: 0.7538 - lr: 5.0000e-07
# Epoch 81/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.1001 - accuracy: 0.9662 - f1: 0.9662 - sensitivity: 0.9662 - specificity: 0.9662 - val_loss: 14.0033 - val_accuracy: 0.7404 - val_f1: 0.7393 - val_sensitivity: 0.7393 - val_specificity: 0.7393 - lr: 5.0000e-07
# Epoch 82/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.0987 - accuracy: 0.9659 - f1: 0.9659 - sensitivity: 0.9659 - specificity: 0.9659 - val_loss: 13.1155 - val_accuracy: 0.7525 - val_f1: 0.7514 - val_sensitivity: 0.7514 - val_specificity: 0.7514 - lr: 5.0000e-07
# Epoch 83/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0985 - accuracy: 0.9663 - f1: 0.9663 - sensitivity: 0.9663 - specificity: 0.9663 - val_loss: 15.1689 - val_accuracy: 0.7360 - val_f1: 0.7350 - val_sensitivity: 0.7350 - val_specificity: 0.7350 - lr: 5.0000e-07
# Epoch 84/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0983 - accuracy: 0.9672 - f1: 0.9672 - sensitivity: 0.9672 - specificity: 0.9672 - val_loss: 14.4306 - val_accuracy: 0.7471 - val_f1: 0.7460 - val_sensitivity: 0.7460 - val_specificity: 0.7460 - lr: 5.0000e-07
# Epoch 85/100
# 1378/1378 [==============================] - 93s 67ms/step - loss: 0.0976 - accuracy: 0.9672 - f1: 0.9672 - sensitivity: 0.9672 - specificity: 0.9672 - val_loss: 14.9941 - val_accuracy: 0.7398 - val_f1: 0.7388 - val_sensitivity: 0.7388 - val_specificity: 0.7388 - lr: 5.0000e-07
# Epoch 86/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0970 - accuracy: 0.9667 - f1: 0.9667 - sensitivity: 0.9667 - specificity: 0.9667 - val_loss: 15.4522 - val_accuracy: 0.7351 - val_f1: 0.7341 - val_sensitivity: 0.7341 - val_specificity: 0.7341 - lr: 5.0000e-07
# Epoch 87/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0986 - accuracy: 0.9664 - f1: 0.9664 - sensitivity: 0.9664 - specificity: 0.9664 - val_loss: 16.3748 - val_accuracy: 0.7286 - val_f1: 0.7276 - val_sensitivity: 0.7276 - val_specificity: 0.7276 - lr: 5.0000e-07
# Epoch 88/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0958 - accuracy: 0.9666 - f1: 0.9666 - sensitivity: 0.9666 - specificity: 0.9666 - val_loss: 15.8616 - val_accuracy: 0.7344 - val_f1: 0.7334 - val_sensitivity: 0.7334 - val_specificity: 0.7334 - lr: 5.0000e-07
# Epoch 89/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0992 - accuracy: 0.9673 - f1: 0.9673 - sensitivity: 0.9673 - specificity: 0.9673 - val_loss: 15.9242 - val_accuracy: 0.7358 - val_f1: 0.7348 - val_sensitivity: 0.7348 - val_specificity: 0.7348 - lr: 5.0000e-07
# Epoch 90/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0969 - accuracy: 0.9665 - f1: 0.9665 - sensitivity: 0.9665 - specificity: 0.9665 - val_loss: 16.2745 - val_accuracy: 0.7351 - val_f1: 0.7341 - val_sensitivity: 0.7341 - val_specificity: 0.7341 - lr: 5.0000e-07
# Epoch 91/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0983 - accuracy: 0.9674 - f1: 0.9674 - sensitivity: 0.9674 - specificity: 0.9674 - val_loss: 17.7293 - val_accuracy: 0.7212 - val_f1: 0.7202 - val_sensitivity: 0.7202 - val_specificity: 0.7202 - lr: 5.0000e-07
# Epoch 92/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0970 - accuracy: 0.9675 - f1: 0.9675 - sensitivity: 0.9675 - specificity: 0.9675 - val_loss: 19.4177 - val_accuracy: 0.7079 - val_f1: 0.7065 - val_sensitivity: 0.7065 - val_specificity: 0.7065 - lr: 5.0000e-07
# Epoch 93/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0972 - accuracy: 0.9665 - f1: 0.9665 - sensitivity: 0.9665 - specificity: 0.9665 - val_loss: 18.6164 - val_accuracy: 0.7164 - val_f1: 0.7150 - val_sensitivity: 0.7150 - val_specificity: 0.7150 - lr: 5.0000e-07
# Epoch 94/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0968 - accuracy: 0.9665 - f1: 0.9665 - sensitivity: 0.9665 - specificity: 0.9665 - val_loss: 18.6681 - val_accuracy: 0.7139 - val_f1: 0.7124 - val_sensitivity: 0.7124 - val_specificity: 0.7124 - lr: 5.0000e-07
# Epoch 95/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.0972 - accuracy: 0.9663 - f1: 0.9662 - sensitivity: 0.9662 - specificity: 0.9662 - val_loss: 18.1165 - val_accuracy: 0.7242 - val_f1: 0.7227 - val_sensitivity: 0.7227 - val_specificity: 0.7227 - lr: 5.0000e-07
# Epoch 96/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0972 - accuracy: 0.9663 - f1: 0.9662 - sensitivity: 0.9662 - specificity: 0.9662 - val_loss: 18.9887 - val_accuracy: 0.7166 - val_f1: 0.7157 - val_sensitivity: 0.7157 - val_specificity: 0.7157 - lr: 5.0000e-07
# Epoch 97/100
# 1378/1378 [==============================] - 93s 68ms/step - loss: 0.0935 - accuracy: 0.9675 - f1: 0.9675 - sensitivity: 0.9675 - specificity: 0.9675 - val_loss: 20.6334 - val_accuracy: 0.7037 - val_f1: 0.7023 - val_sensitivity: 0.7023 - val_specificity: 0.7023 - lr: 5.0000e-07
# Epoch 98/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0963 - accuracy: 0.9668 - f1: 0.9668 - sensitivity: 0.9668 - specificity: 0.9668 - val_loss: 20.7118 - val_accuracy: 0.7041 - val_f1: 0.7032 - val_sensitivity: 0.7032 - val_specificity: 0.7032 - lr: 5.0000e-07
# Epoch 99/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0967 - accuracy: 0.9675 - f1: 0.9675 - sensitivity: 0.9675 - specificity: 0.9675 - val_loss: 21.4629 - val_accuracy: 0.7025 - val_f1: 0.7010 - val_sensitivity: 0.7010 - val_specificity: 0.7010 - lr: 5.0000e-07
# Epoch 100/100
# 1378/1378 [==============================] - 94s 68ms/step - loss: 0.0970 - accuracy: 0.9668 - f1: 0.9668 - sensitivity: 0.9668 - specificity: 0.9668 - val_loss: 21.0180 - val_accuracy: 0.7066 - val_f1: 0.7057 - val_sensitivity: 0.7057 - val_specificity: 0.7057 - lr: 5.0000e-07

# %%
print('------------Training time is seconds:%s',time.time()-start_time)
scores = model.evaluate(x_test, y_test, verbose=1)

#history keys and values
print(history.history.keys())
print(history.history.values())

#Metrics for testing
print(scores)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
print('Test f1:',scores[2])
print('Test sensitivity:',scores[3])
print('Test specificity:',scores[4])
print("Max Test accuracy", max(history.history['val_accuracy']))
# Out:
# ------------Training time is seconds:%s 10318.08790898323
# 173/173 [==============================] - 2s 14ms/step - loss: 21.0180 - accuracy: 0.7066 - f1: 0.7057 - sensitivity: 0.7057 - specificity: 0.7057
# dict_keys(['loss', 'accuracy', 'f1', 'sensitivity', 'specificity', 'val_loss', 'val_accuracy', 'val_f1', 'val_sensitivity', 'val_specificity', 'lr'])
# dict_values([[0.3504314124584198, 0.1770816594362259, 0.1616358608007431, 0.14949189126491547, 0.12708188593387604, 0.12226053327322006, 0.11097189038991928, 0.11074025183916092, 0.10536908358335495, 0.10711054503917694, 0.10650721937417984, 0.10484899580478668, 0.10539739578962326, 0.10312582552433014, 0.10330159217119217, 0.10294536501169205, 0.10313361883163452, 0.10306428372859955, 0.10363636910915375, 0.10388538241386414, 0.10356530547142029, 0.10252772271633148, 0.09905999898910522, 0.10388176143169403, 0.1014794409275055, 0.10235633701086044, 0.10116755962371826, 0.10266046971082687, 0.10518509894609451, 0.10172433406114578, 0.1017448902130127, 0.10228779911994934, 0.10242705047130585, 0.10072201490402222, 
# [21.017963409423828, 0.7066400647163391, 0.7057441473007202, 0.705744206905365, 0.705744206905365]
# Test loss: 21.017963409423828
# Test accuracy: 0.7066400647163391
# Test f1: 0.7057441473007202
# Test sensitivity: 0.705744206905365
# Test specificity: 0.705744206905365
# Max Test accuracy 0.9564586281776428

# %%
import matplotlib.pyplot as plt
# summarize history for accuracy

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig(METRICS_PATH+MODEL_NAME+"_acc.png")
plt.show()

# %%
# summarize history for loss

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig(METRICS_PATH+MODEL_NAME+"_loss.png")
plt.show()

# %% [markdown]
# ### Without Augumentation

# %%
MODEL_NAME="AlexNet_waug"

# %%
batch_size = 16
data_augmentation = False
epochs = 100

# %%
import time
start_time = time.time()

if not data_augmentation:
    print('Not using data augmentation.')
    history = model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True, callbacks=[lr_reducer,csv_logger])
else:
    print('Using real-time data augmentation.')
    datagen = ImageDataGenerator(
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True)  # randomly flip images
    datagen.fit(x_train)
    history = model.fit_generator(datagen.flow(x_train, y_train,
                                               batch_size=batch_size),
                                  epochs=epochs,
                                  validation_data=(x_test, y_test), callbacks=[lr_reducer, csv_logger])
# Out:
# Not using data augmentation.
# Epoch 1/100
# 393/393 [==============================] - 37s 66ms/step - loss: 0.2462 - accuracy: 0.9031 - f1: 0.9031 - sensitivity: 0.9031 - specificity: 0.9031 - val_loss: 0.3659 - val_accuracy: 0.8384 - val_f1: 0.8396 - val_sensitivity: 0.8396 - val_specificity: 0.8396 - lr: 6.0000e-05
# Epoch 2/100
# 393/393 [==============================] - 25s 63ms/step - loss: 0.1566 - accuracy: 0.9386 - f1: 0.9386 - sensitivity: 0.9386 - specificity: 0.9386 - val_loss: 0.1283 - val_accuracy: 0.9504 - val_f1: 0.9508 - val_sensitivity: 0.9508 - val_specificity: 0.9508 - lr: 6.0000e-05
# Epoch 3/100
# 393/393 [==============================] - 25s 64ms/step - loss: 0.1304 - accuracy: 0.9491 - f1: 0.9491 - sensitivity: 0.9491 - specificity: 0.9491 - val_loss: 0.1033 - val_accuracy: 0.9599 - val_f1: 0.9602 - val_sensitivity: 0.9602 - val_specificity: 0.9602 - lr: 6.0000e-05
# Epoch 4/100
# 393/393 [==============================] - 25s 64ms/step - loss: 0.1072 - accuracy: 0.9604 - f1: 0.9604 - sensitivity: 0.9604 - specificity: 0.9604 - val_loss: 0.0945 - val_accuracy: 0.9650 - val_f1: 0.9653 - val_sensitivity: 0.9653 - val_specificity: 0.9653 - lr: 6.0000e-05
# Epoch 5/100
# 393/393 [==============================] - 25s 65ms/step - loss: 0.0969 - accuracy: 0.9664 - f1: 0.9664 - sensitivity: 0.9664 - specificity: 0.9664 - val_loss: 0.1232 - val_accuracy: 0.9663 - val_f1: 0.9665 - val_sensitivity: 0.9665 - val_specificity: 0.9665 - lr: 6.0000e-05
# Epoch 6/100
# 393/393 [==============================] - 25s 64ms/step - loss: 0.0847 - accuracy: 0.9666 - f1: 0.9665 - sensitivity: 0.9665 - specificity: 0.9665 - val_loss: 0.1273 - val_accuracy: 0.9542 - val_f1: 0.9545 - val_sensitivity: 0.9545 - val_specificity: 0.9545 - lr: 6.0000e-05
# Epoch 7/100
# 393/393 [==============================] - 25s 64ms/step - loss: 0.0494 - accuracy: 0.9817 - f1: 0.9817 - sensitivity: 0.9817 - specificity: 0.9817 - val_loss: 0.1036 - val_accuracy: 0.9726 - val_f1: 0.9729 - val_sensitivity: 0.9729 - val_specificity: 0.9729 - lr: 1.8974e-05
# Epoch 8/100
# 393/393 [==============================] - 25s 64ms/step - loss: 0.0328 - accuracy: 0.9874 - f1: 0.9874 - sensitivity: 0.9874 - specificity: 0.9874 - val_loss: 0.1527 - val_accuracy: 0.9688 - val_f1: 0.9691 - val_sensitivity: 0.9691 - val_specificity: 0.9691 - lr: 1.8974e-05
# Epoch 9/100
# 393/393 [==============================] - 25s 65ms/step - loss: 0.0171 - accuracy: 0.9928 - f1: 0.9928 - sensitivity: 0.9928 - specificity: 0.9928 - val_loss: 0.1479 - val_accuracy: 0.9682 - val_f1: 0.9684 - val_sensitivity: 0.9684 - val_specificity: 0.9684 - lr: 6.0000e-06
# Epoch 10/100
# 393/393 [==============================] - 25s 64ms/step - loss: 0.0129 - accuracy: 0.9955 - f1: 0.9955 - sensitivity: 0.9955 - specificity: 0.9955 - val_loss: 0.1662 - val_accuracy: 0.9720 - val_f1: 0.9722 - val_sensitivity: 0.9722 - val_specificity: 0.9722 - lr: 6.0000e-06
# Epoch 11/100
# 393/393 [==============================] - 25s 65ms/step - loss: 0.0091 - accuracy: 0.9960 - f1: 0.9960 - sensitivity: 0.9960 - specificity: 0.9960 - val_loss: 0.1687 - val_accuracy: 0.9726 - val_f1: 0.9729 - val_sensitivity: 0.9729 - val_specificity: 0.9729 - lr: 1.8974e-06
# Epoch 12/100
# 393/393 [==============================] - 25s 64ms/step - loss: 0.0083 - accuracy: 0.9971 - f1: 0.9971 - sensitivity: 0.9971 - specificity: 0.9971 - val_loss: 0.1843 - val_accuracy: 0.9707 - val_f1: 0.9710 - val_sensitivity: 0.9710 - val_specificity: 0.9710 - lr: 1.8974e-06
# Epoch 13/100
# 393/393 [==============================] - 25s 63ms/step - loss: 0.0065 - accuracy: 0.9976 - f1: 0.9976 - sensitivity: 0.9976 - specificity: 0.9976 - val_loss: 0.1847 - val_accuracy: 0.9695 - val_f1: 0.9697 - val_sensitivity: 0.9697 - val_specificity: 0.9697 - lr: 6.0000e-07
# Epoch 14/100
# 393/393 [==============================] - 25s 65ms/step - loss: 0.0064 - accuracy: 0.9975 - f1: 0.9975 - sensitivity: 0.9975 - specificity: 0.9975 - val_loss: 0.1893 - val_accuracy: 0.9714 - val_f1: 0.9716 - val_sensitivity: 0.9716 - val_specificity: 0.9716 - lr: 6.0000e-07
# Epoch 15/100
# 393/393 [==============================] - 25s 65ms/step - loss: 0.0058 - accuracy: 0.9981 - f1: 0.9981 - sensitivity: 0.9981 - specificity: 0.9981 - val_loss: 0.1939 - val_accuracy: 0.9688 - val_f1: 0.9691 - val_sensitivity: 0.9691 - val_specificity: 0.9691 - lr: 5.0000e-07
# Epoch 16/100
# 393/393 [==============================] - 25s 65ms/step - loss: 0.0054 - accuracy: 0.9982 - f1: 0.9983 - sensitivity: 0.9983 - specificity: 0.9983 - val_loss: 0.1948 - val_accuracy: 0.9701 - val_f1: 0.9703 - val_sensitivity: 0.9703 - val_specificity: 0.9703 - lr: 5.0000e-07
# Epoch 17/100
# 393/393 [==============================] - 25s 65ms/step - loss: 0.0052 - accuracy: 0.9984 - f1: 0.9984 - sensitivity: 0.9984 - specificity: 0.9984 - val_loss: 0.1958 - val_accuracy: 0.9695 - val_f1: 0.9697 - val_sensitivity: 0.9697 - val_specificity: 0.9697 - lr: 5.0000e-07
# Epoch 18/100
# 393/393 [==============================] - 25s 65ms/step - loss: 0.0056 - accuracy: 0.9982 - f1: 0.9983 - sensitivity: 0.9983 - specificity: 0.9983 - val_loss: 0.1998 - val_accuracy: 0.9701 - val_f1: 0.9703 - val_sensitivity: 0.9703 - val_specificity: 0.9703 - lr: 5.0000e-07
# Epoch 19/100
# 393/393 [==============================] - 25s 64ms/step - loss: 0.0065 - accuracy: 0.9971 - f1: 0.9971 - sensitivity: 0.9971 - specificity: 0.9971 - val_loss: 0.1977 - val_accuracy: 0.9701 - val_f1: 0.9703 - val_sensitivity: 0.9703 - val_specificity: 0.9703 - lr: 5.0000e-07
# Epoch 20/100
# 393/393 [==============================] - 25s 64ms/step - loss: 0.0063 - accuracy: 0.9975 - f1: 0.9975 - sensitivity: 0.9975 - specificity: 0.9975 - val_loss: 0.2009 - val_accuracy: 0.9695 - val_f1: 0.9697 - val_sensitivity: 0.9697 - val_specificity: 0.9697 - lr: 5.0000e-07
# Epoch 21/100
# 393/393 [==============================] - 25s 64ms/step - loss: 0.0052 - accuracy: 0.9981 - f1: 0.9980 - sensitivity: 0.9980 - specificity: 0.9980 - val_loss: 0.2018 - val_accuracy: 0.9695 - val_f1: 0.9697 - val_sensitivity: 0.9697 - val_specificity: 0.9697 - lr: 5.0000e-07
# Epoch 22/100
# 393/393 [==============================] - 25s 64ms/step - loss: 0.0049 - accuracy: 0.9979 - f1: 0.9979 - sensitivity: 0.9979 - specificity: 0.9979 - val_loss: 0.2023 - val_accuracy: 0.9701 - val_f1: 0.9703 - val_sensitivity: 0.9703 - val_specificity: 0.9703 - lr: 5.0000e-07
# Epoch 23/100
# 393/393 [==============================] - 25s 64ms/step - loss: 0.0047 - accuracy: 0.9982 - f1: 0.9983 - sensitivity: 0.9983 - specificity: 0.9983 - val_loss: 0.2046 - val_accuracy: 0.9701 - val_f1: 0.9703 - val_sensitivity: 0.9703 - val_specificity: 0.9703 - lr: 5.0000e-07
# Epoch
-04 - accuracy: 0.9997 - f1: 0.9997 - sensitivity: 0.9997 - specificity: 0.9997 - val_loss: 0.2812 - val_accuracy: 0.9714 - val_f1: 0.9716 - val_sensitivity: 0.9716 - val_specificity: 0.9716 - lr: 5.0000e-07
# Epoch 97/100
# 393/393 [==============================] - 26s 65ms/step - loss: 7.3575e-04 - accuracy: 0.9998 - f1: 0.9998 - sensitivity: 0.9998 - specificity: 0.9998 - val_loss: 0.2809 - val_accuracy: 0.9701 - val_f1: 0.9703 - val_sensitivity: 0.9703 - val_specificity: 0.9703 - lr: 5.0000e-07
# Epoch 98/100
# 393/393 [==============================] - 25s 64ms/step - loss: 7.7708e-04 - accuracy: 0.9997 - f1: 0.9997 - sensitivity: 0.9997 - specificity: 0.9997 - val_loss: 0.2858 - val_accuracy: 0.9701 - val_f1: 0.9703 - val_sensitivity: 0.9703 - val_specificity: 0.9703 - lr: 5.0000e-07
# Epoch 99/100
# 393/393 [==============================] - 25s 64ms/step - loss: 8.2823e-04 - accuracy: 0.9997 - f1: 0.9997 - sensitivity: 0.9997 - specificity: 0.9997 - val_loss: 0.2867 - val_accuracy: 0.9720 - val_f1: 0.9722 - val_sensitivity: 0.9722 - val_specificity: 0.9722 - lr: 5.0000e-07
# Epoch 100/100
# 393/393 [==============================] - 25s 65ms/step - loss: 7.1246e-04 - accuracy: 1.0000 - f1: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_loss: 0.2882 - val_accuracy: 0.9720 - val_f1: 0.9722 - val_sensitivity: 0.9722 - val_specificity: 0.9722 - lr: 5.0000e-07

# %%
print('------------Training time is seconds:%s',time.time()-start_time)
scores = model.evaluate(x_test, y_test, verbose=1)

#history keys and values
print(history.history.keys())
print(history.history.values())

#Metrics for testing
print(scores)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
print('Test f1:',scores[2])
print('Test sensitivity:',scores[3])
print('Test specificity:',scores[4])
print("Max Test accuracy", max(history.history['val_accuracy']))
# Out:
# ------------Training time is seconds:%s 2630.7206501960754
# 50/50 [==============================] - 1s 14ms/step - loss: 0.2882 - accuracy: 0.9720 - f1: 0.9725 - sensitivity: 0.9725 - specificity: 0.9725
# dict_keys(['loss', 'accuracy', 'f1', 'sensitivity', 'specificity', 'val_loss', 'val_accuracy', 'val_f1', 'val_sensitivity', 'val_specificity', 'lr'])
# dict_values([[0.24616999924182892, 0.1566057652235031, 0.13043253123760223, 0.10721614956855774, 0.09685515612363815, 0.08468697220087051, 0.049386393278837204, 0.03280853480100632, 0.0170543622225523, 0.01290891133248806, 0.009118407033383846, 0.008269808255136013, 0.006540771573781967, 0.006359508726745844, 0.00584119139239192, 0.005449969321489334, 0.005160050000995398, 0.005564045161008835, 0.0064671519212424755, 0.0062876190058887005, 0.005209287628531456, 0.004927061498165131, 0.004713218659162521, 0.004478469491004944, 0.005132561083883047, 0.00460826838389039, 0.004158451221883297, 0.003411215031519532, 0.0032032770104706287, 0.0037069234531372786, 0.0032189416233450174, 0.00425191642716527, 0.003469511168077588, 0.003479624632745981, 0.004408028442412615, 0.004195274319499731, 0.002429504645988345, 0.0028371927328407764, 0.0027573462575674057, 0.0028125662356615067, 0.0022764718160033226, 0.003262209240347147, 0.003292424837127328, 0.0016778528224676847, 0.0020936597138643265, 0.0021224443335086107, 0.0028052383568137884, 0.001740902429446578, 0.0021358802914619446, 0.0017554076621308923, 0.002931217895820737, 0.002197535475715995, 0.001971866236999631, 0.0018966506468132138, 0.0014604738680645823, 0.0019903467036783695, 0.0015511459205299616, 0.0016017281450331211, 0.0022509670816361904, 0.001818622462451458, 0.001206668559461832, 0.0015146401710808277, 0.0017207727069035172, 0.0015071567613631487, 0.0014